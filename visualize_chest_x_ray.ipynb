# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
def show_image_with_dimensions(image_path):

    img = Image.open(image_path).convert("L")
    
    width, height = img.size
    print(f"Dimensiones de la imagen: {width} x {height}")

    plt.imshow(img, cmap="gray")
    plt.axis("off")  # Ocultar ejes
    plt.title(f"Tamaño: {width} x {height}")
    plt.show()

# %%
open_path="/home/lchanch/initial_image_prepro/downsample_img_256/p10/p10000032/s50414267/02aa804e-bde0afdd-112c0b34-7bc16630-4e384014.png"
show_image_with_dimensions(open_path)
# Out:
# Dimensiones de la imagen: 256 x 307
